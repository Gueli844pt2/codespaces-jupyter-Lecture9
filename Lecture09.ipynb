# %%
stringData = """
    "temp": [89,72,63,90,88,76,81],
    "pressure": [9,9,10,9,8,7,6],
    "humidity":[20,33,90,100,88,38,79]
"""

# %%
stringData.split()
# Out:
# ['"temp":',
#  '[89,72,63,90,88,76,81],',
#  '"pressure":',
#  '[9,9,10,9,8,7,6],',
#  '"humidity":[20,33,90,100,88,38,79]']

# %%
[line for line in stringData.split('\n') if len(line)>0]
# Out:
# ['    "temp": [89,72,63,90,88,76,81],',
#  '    "pressure": [9,9,10,9,8,7,6],',
#  '    "humidity":[20,33,90,100,88,38,79]']

# %%
[line.split(":") for line in stringData.split('\n') if len(line)>0]
# Out:
# [['    "temp"', ' [89,72,63,90,88,76,81],'],
#  ['    "pressure"', ' [9,9,10,9,8,7,6],'],
#  ['    "humidity"', '[20,33,90,100,88,38,79]']]

# %%
weather = {"temp": [89,72,63,90,88,76,81],
"pressure": [9,9,10,9,8,7,6]}

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
weather_table = pd.DataFrame(weather)

# %%
weather_table
# Out:
#    temp  pressure
# 0    89         9
# 1    72         9
# 2    63        10
# 3    90         9
# 4    88         8
# 5    76         7
# 6    81         6

# %%
weather_table['temp']
# Out:
# 0    89
# 1    72
# 2    63
# 3    90
# 4    88
# 5    76
# 6    81
# Name: temp, dtype: int64

# %%
type(weather_table['temp'])
# Out:
# pandas.core.series.Series

# %%
weather_table.columns
# Out:
# Index(['temp', 'pressure'], dtype='object')

# %%
weather_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   temp      7 non-null      int64
#  1   pressure  7 non-null      int64
# dtypes: int64(2)
# memory usage: 240.0 bytes

# %%
weather2 = np.array([[89,72,63,90,88,76,81],
[9,9,10,9,8,7,6],
[20,33,90,100,88,38,79]]).transpose()

# %%
weather_table2 = pd.DataFrame(weather2)

# %%
weather_table2
# Out:
#     0   1    2
# 0  89   9   20
# 1  72   9   33
# 2  63  10   90
# 3  90   9  100
# 4  88   8   88
# 5  76   7   38
# 6  81   6   79

# %%
columns = ["temp","pressure","humidity"]

# %%
weather_table2
# Out:
#    temp  pressure  humidity
# 0    89         9        20
# 1    72         9        33
# 2    63        10        90
# 3    90         9       100
# 4    88         8        88
# 5    76         7        38
# 6    81         6        79

# %%
weather_df = pd.DataFrame(weather2,columns=columns)
weather_df
# Out:
#    temp  pressure  humidity
# 0    89         9        20
# 1    72         9        33
# 2    63        10        90
# 3    90         9       100
# 4    88         8        88
# 5    76         7        38
# 6    81         6        79

# %%
days = [1,2,3,4,5,6,7]
weather_df2 = pd.DataFrame(weather2,index=days,columns=columns)
weather_df2
# Out:
#    temp  pressure  humidity
# 1    89         9        20
# 2    72         9        33
# 3    63        10        90
# 4    90         9       100
# 5    88         8        88
# 6    76         7        38
# 7    81         6        79

# %%
happy_df = pd.read_csv("https://raw.githubusercontent.com/mdogy/dataForEng1999/master/Happyness2019.csv")

# %%
happy_df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
happy_df.head(15)
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland  7.769           1.340           1.587
# 1              2           Denmark  7.600           1.383           1.573
# 2              3            Norway  7.554           1.488           1.582
# 3              4           Iceland  7.494           1.380           1.624
# 4              5       Netherlands  7.488           1.396           1.522
# 5              6       Switzerland  7.480           1.452           1.526
# 6              7            Sweden  7.343           1.387           1.487
# 7              8       New Zealand  7.307           1.303           1.557
# 8              9            Canada  7.278           1.365           1.505
# 9             10           Austria  7.246           1.376           1.475
# 10            11         Australia  7.228           1.372           1.548
# 11            12        Costa Rica  7.167           1.034           1.441
# ...

# %%
happy_df.head(20)
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland  7.769           1.340           1.587
# 1              2           Denmark  7.600           1.383           1.573
# 2              3            Norway  7.554           1.488           1.582
# 3              4           Iceland  7.494           1.380           1.624
# 4              5       Netherlands  7.488           1.396           1.522
# 5              6       Switzerland  7.480           1.452           1.526
# 6              7            Sweden  7.343           1.387           1.487
# 7              8       New Zealand  7.307           1.303           1.557
# 8              9            Canada  7.278           1.365           1.505
# 9             10           Austria  7.246           1.376           1.475
# 10            11         Australia  7.228           1.372           1.548
# 11            12        Costa Rica  7.167           1.034           1.441
# ...

# %%
happy_df["Score"]
# Out:
# 0      7.769
# 1      7.600
# 2      7.554
# 3      7.494
# 4      7.488
#        ...
# 151    3.334
# 152    3.231
# 153    3.203
# 154    3.083
# 155    2.853
# Name: Score, Length: 156, dtype: float64

# %%
short_df = happy_df[["Country or region","Score"]]

# %%
type(short_df)
# Out:
# pandas.core.frame.DataFrame

# %%
short_df.iloc[15:25]
# Out:
#        Country or region  Score
# 15               Ireland  7.021
# 16               Germany  6.985
# 17               Belgium  6.923
# 18         United States  6.892
# 19        Czech Republic  6.852
# 20  United Arab Emirates  6.825
# 21                 Malta  6.726
# 22                Mexico  6.595
# 23                France  6.592
# 24                Taiwan  6.446

# %%
happy_df.loc[15:25,"Overall rank":"Social support"]
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support
# 15            16               Ireland  7.021           1.499           1.553
# 16            17               Germany  6.985           1.373           1.454
# 17            18               Belgium  6.923           1.356           1.504
# 18            19         United States  6.892           1.433           1.457
# 19            20        Czech Republic  6.852           1.269           1.487
# 20            21  United Arab Emirates  6.825           1.503           1.310
# 21            22                 Malta  6.726           1.300           1.520
# 22            23                Mexico  6.595           1.070           1.323
# 23            24                France  6.592           1.324           1.472
# 24            25                Taiwan  6.446           1.368           1.430
# 25            26                 Chile  6.444           1.159           1.369

# %%
happy_df.Score
# Out:
# 0      7.769
# 1      7.600
# 2      7.554
# 3      7.494
# 4      7.488
#        ...
# 151    3.334
# 152    3.231
# 153    3.203
# 154    3.083
# 155    2.853
# Name: Score, Length: 156, dtype: float64

# %%
happy_df.loc[(happy_df.Score < 7.0) & ((happy_df.Score > 6.0))]
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 16            17               Germany  6.985           1.373           1.454
# 17            18               Belgium  6.923           1.356           1.504
# 18            19         United States  6.892           1.433           1.457
# 19            20        Czech Republic  6.852           1.269           1.487
# 20            21  United Arab Emirates  6.825           1.503           1.310
# 21            22                 Malta  6.726           1.300           1.520
# 22            23                Mexico  6.595           1.070           1.323
# 23            24                France  6.592           1.324           1.472
# 24            25                Taiwan  6.446           1.368           1.430
# 25            26                 Chile  6.444           1.159           1.369
# 26            27             Guatemala  6.436           0.800           1.269
# ...

# %%
happy_df.Sofd.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2645/3401403491.py in ?()
# ----> 1 happy_df.Sofd.mean()
#
# ~/.python/current/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Sofd'

# %%
happy_df.Score.count()/2
# Out:
# 78.0
